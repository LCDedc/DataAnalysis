# %% [markdown]
# # 分类数据的非参数检验(比例检验)
# * 参数检验与非参数检验
#     * 参数检验是对均值、标准差等总体参数的检验
#     * 非参数检验不计算均值、标准差等参数, 通常计算中位数、秩(排位)
# * 不满足参数检验(均值推断)条件时, 则可使用非参数检验, 例如:
#     * 是分类数据、有序数据
#     * 有极端值、有缺失数据
#     * 总体是非正态、方差不齐的, 且样本容量较小
# * 条件满足时, 参数检验优于非参数检验

# %% [markdown]
# ## 二项检验(拟合度检验)
# * 两个类别的比例, 符合预期吗?
# * 例子
#     * 从该地大学生群体中随机抽取1000人，发现63人感染新冠病毒
#     * 该地大学生感染率等于0.08(该地整体感染率)吗？

# %%
from scipy import stats
stats.binomtest(63,n=1000,p=0.08) # 默认为双尾检验
# Out:
# BinomTestResult(k=63, n=1000, alternative='two-sided', proportion_estimate=0.063, pvalue=0.047384261558837196)

# %% [markdown]
# * 当n足够大(确保n×p和n×(1-p)都≥10)时, 随机变量X(事件发生次数)近似服均值为n×p、方差为n×p×(1-p)的从正态分布

# %% [markdown]
# ## 单因素卡方检验(拟合度检验)
# * 多个类别的比例, 符合预期吗?
# * 单因素卡方检验, Chi2-oneway-test, 也叫: 拟合度的卡方检验
# * 原假设: 观察值符合预计值, 各类别比例符合预期

# %% [markdown]
# ### 两个类别的比例, 符合预期吗?
# * 对两个类别比例做卡方检验, 与二项检验等价
# * 案例
#     * 参见excel表格
#     * 原假设: 观察值等于期望数

# %%
from scipy import stats
stats.chisquare(f_obs=[63,937], f_exp=[80,920])
# Out:
# Power_divergenceResult(statistic=3.9266304347826084, pvalue=0.04752708320015089)

# %% [markdown]
# * p值小于0.05, 拒绝原假设, 观察值不符合预计值
# * 注意, 卡方检验必然为单尾检验(拒绝域在右尾), p值是统计量大于样本卡方值的概率

# %% [markdown]
# ### 多个类别的比例, 符合预期吗?
# * 超过2个类别时, 只能做卡方检验, 不能做二项检验
# * 案例
#     * 参见excel表格
#     * 原假设: 4个类别的比例都相等(=0.25)

# %%
stats.chisquare(f_obs=[18,17,7,8])   #f_exp=默认值为等概率
# Out:
# Power_divergenceResult(statistic=8.08, pvalue=0.044386959367383204)

# %% [markdown]
# ## 双因素卡方检验(独立性检验)
# * 双因素卡方检验, 也叫: 双因素的独立性卡方检验，列联表卡方检验
# * 多个类别的比例, 符合预期吗?
# * 两因素(两个分类变量), 对各类别的比例有影响吗?

# %% [markdown]
# ### 例子: 双因素卡方检验
# * 问题: 是否少数族裔, 与成为公司经理相关吗?
# * 参见excel表格
# * 原假设: 两因素没有影响, 是否少数族裔与成为公司经理**不相关**

# %%
import pandas as pd
data = pd.read_excel('10 非参数统计检验.xlsx',sheet_name='双因素卡方检验-数据',index_col=0)  
# 指定第一列为行索引
data
# Out:
#        0否-少数族裔  1是-少数族裔
# 0否-经理      290      100
# 1是-经理       80        4

# %%
from scipy import stats
stats.chi2_contingency(data, correction=False)  
#卡方检验, 不对卡方值做修正,与excel保持一致
# Out:
# (17.591853053391514,
#  2.7375863373913508e-05,
#  1,
#  array([[304.43037975,  85.56962025],
#         [ 65.56962025,  18.43037975]]))

# %% [markdown]
# * p值远小于0.05, 拒绝原假设, 是否少数族裔与成为公司经理**相关**

# %% [markdown]
# ### 改进: Fisher精确检验
# * 卡方检验基于近似分布(n很大的二项分布近似正态分布)计算概率, 手工计算较方便
# * 现在, 用软件计算2*2列联表(四格表)的精确概率已十分方便, 称之为Fisher精确检验
#     * 对2*2列联表, 若不满足80%单元格期望值至少为5的要求，应使用Fisher精确检验
#     * 对2*2列联表, 若采用卡方检验得到的P值在0.05附近时，应使用Fisher精确检验
#     * 有文献认为，对于未进行配对的2*2列联表，任何时候都应使用Fisher精确检验

# %%
from scipy import stats
stats.fisher_exact(data)
# Out:
# (0.145, 4.343269259230122e-06)

# %% [markdown]
# * 第2个参数为p值, 远小于0.05, 拒绝原假设, 是否少数族裔与成为公司经理**相关**

# %% [markdown]
# ## 案例应用: 基于原始数据
# ### 常见的原始数据组织形式
# * subj列为编号, 共60个被试
# * ge_gender列为性别
# * pa_political_affiliation列为政党属性

# %%
import pandas as pd
data = pd.read_excel('9 回归分析.xlsx', sheet_name='student-survey')
data
# Out:
#     subj  co_college_GPA  co_college_GPA_100  hi_high_school_GPA ge_gender  \
# 0      1             3.5                87.5                 2.2         m
# 1      2             3.5                87.5                 2.1         f
# 2      3             3.0                75.0                 3.3         f
# 3      4             3.2                80.0                 3.5         f
# 4      5             3.5                87.5                 3.1         m
# 5      6             3.5                87.5                 3.5         m
# 6      7             3.7                92.5                 3.6         m
# 7      8             3.0                75.0                 3.0         f
# 8      9             3.0                75.0                 3.0         m
# 9     10             3.1                77.5                 4.0         m
# 10    11             2.6                65.0                 2.3         m
# 11    12             3.6                90.0                 3.5         f
# 12    13             3.5                87.5                 3.3         m
# 13    14             3.2                80.0                 3.2         m
# 14    15             3.5                87.5                 3.0         f
# 15    16             3.3                82.5                 3.8         f
# 16    17             3.0                75.0                 4.0         f
# 17    18             3.8                95.0                 3.8         m
# 18    19             3.5                87.5                 4.0         m
# 19    20             3.8                95.0                 3.0         f
# 20    21             3.7                92.5                 3.7         f
# 21    22             3.7                92.5                 4.0         f
# 22    23             3.5                87.5                 2.7         m
# 23    24             3.7                92.5                 3.7         f
# 24    25             3.8                95.0                 3.2         m
# 25    26             3.0                75.0                 3.0         f
# 26    27             3.0                75.0                 3.7         m
# 27    28             3.8                95.0                 3.7         f
# 28    29             3.1                77.5                 3.3         m
# 29    30             3.3                82.5                 3.3         f
# 30    31             3.5                87.5                 3.3         m
# 31    32             3.9                97.5                 3.5         f
# 32    33             3.4                85.0                 3.4         m
# 33    34             2.8                70.0                 3.2         f
# 34    35             3.9                97.5                 3.5         f
# 35    36             3.3                82.5                 3.6         m
# 36    37             3.7                92.5                 3.8         m
# 37    38             3.4                85.0                 3.4         m
# 38    39             3.2                80.0                 2.8         m
# 39    40             3.5                87.5                 3.8         m
# 40    41             3.4                85.0                 3.4         m
# 41    42             3.0                75.0                 2.0         m
# 42    43             3.9                97.5                 3.8         f
# 43    44             3.6                90.0                 3.0         m
# 44    45             4.0               100.0                 3.0         f
# 45    46             3.5                87.5                 3.0         f
# 46    47             3.8                95.0                 3.0         f
# 47    48             3.8                95.0                 3.3         m
# 48    49             4.0               100.0                 3.8         f
# 49    50             4.0               100.0                 3.0         f
# 50    51             3.0                75.0                 3.0         m
# 51    52             4.0               100.0                 4.0         f
# 52    53             3.9                97.5                 3.0         f
# 53    54             3.8                95.0                 3.5         f
# 54    55             3.7                92.5                 3.4         f
# 55    56             3.2                80.0                 3.6         f
# 56    57             3.6                90.0                 3.5         m
# 57    58             3.0                75.0                 3.0         m
# 58    59             3.0                75.0                 3.0         f
# 59    60             3.0                75.0                 3.4         f
#
#    pa_political_affiliation  ag_age  dh_distance_of_campus_from_home  \
# 0                         r      32                                0
# 1                         d      23                             1200
# 2                         d      27                             1300
# 3                         i      35                             1500
# 4                         i      23                             1600
# 5                         d      39                              350
# 6                         i      24                                0
# 7                         i      31                             5000
# 8                         i      34                             5000
# 9                         i      28                              900
# 10                        r      23                              253
# 11                        d      27                              190
# 12                        d      36                              245
# 13                        i      28                              500
# 14                        d      28                             3500
# 15                        i      25                              210
# 16                        i      41                             1000
# 17                        d      50                                0
# 18                        i      71                             5000
# 19                        d      28                              120
# 20                        i      26                             8000
# 21                        i      27                                2
# 22                        r      31                             1700
# 23                        i      23                                2
# 24                        i      23                              450
# 25                        i      44                                0
# 26                        d      26                             1000
# 27                        r      31                              850
# 28                        d      24                              420
# 29                        r      26                             1200
# 30                        d      26                             1000
# 31                        d      32                              150
# 32                        d      26                             2000
# 33                        i      22                              316
# 34                        d      24                              900
# 35                        r      24                              250
# 36                        i      23                              180
# 37                        i      33                             6000
# 38                        r      23                              950
# 39                        r      31                             1100
# 40                        i      26                             1300
# 41                        d      28                              360
# 42                        r      24                             1800
# 43                        r      23                              900
# 44                        i      25                             5000
# 45                        d      24                              300
# 46                        r      27                             2000
# 47                        r      24                              630
# 48                        d      26                             1200
# 49                        d      27                              580
# 50                        r      32                             2000
# 51                        r      41                                0
# 52                        d      29                              300
# 53                        d      50                                6
# 54                        i      22                               80
# 55                        r      23                              375
# 56                        d      26                             2000
# 57                        i      30                                1
# 58                        i      23                              112
# 59                        i      22                              650
#
#     religion     dr    tv  sp  ne  ah ve  pi  re ab aa ld
# 0        1.0   5.00   3.0   5   0   0  n   6   2  n  n  y
# 1        NaN   0.30  15.0   7   5   6  y   2   1  y  y  u
# 2        NaN   1.50   0.0   4   3   0  y   2   2  y  y  u
# 3        0.0   8.00   5.0   5   6   3  n   4   1  y  y  n
# 4        0.0  10.00   6.0   6   3   0  n   1   0  y  n  n
# 5        NaN   3.00   4.0   5   7   0  y   2   1  y  y  u
# 6        1.0   0.20   5.0  12   4   2  n   2   1  y  y  y
# 7        1.0   1.50   5.0   3   3   1  n   2   1  y  y  y
# 8        NaN   2.00   7.0   5   3   0  n   1   1  y  y  u
# 9        1.0   2.00   1.0   1   2   1  y   3   0  n  y  y
# 10       1.0   1.50  10.0  15   1   1  n   5   1  n  y  y
# 11       NaN   3.00  14.0   3   7   0  n   2   1  y  y  u
# 12       1.0   1.50   6.0  15  12   5  n   1   1  y  y  y
# 13       1.0   6.00   3.0  10   1   2  n   4   1  y  n  y
# 14       1.0   1.00   4.0   3   1   0  n   1   0  y  y  y
# 15       1.0  10.00   7.0   6   1   0  y   2   3  y  y  y
# 16       1.0  15.00   6.0   7   3  10  n   3   3  n  u  y
# 17       0.0   3.00   5.0   9   6  10  n   2   0  y  n  n
# 18       0.0   3.00   6.0  12   2   2  n   2   0  y  n  n
# 19       1.0   1.00  25.0   0   0   2  y   1   1  y  y  y
# 20       1.0   8.00   4.0   4   4   1  n   4   1  y  y  y
# 21       1.0   2.50   4.0   2   7   0  n   2   1  y  y  y
# 22       1.0   5.00   7.0   7   2   0  n   7   3  n  n  y
# 23       1.0   2.00   7.0   4   2   0  n   4   0  y  y  y
# 24       1.0   4.00   0.0   7   7   3  n   1   0  y  y  y
# 25       1.0   2.00   2.0   3   2   3  y   3   2  y  y  y
# 26       NaN   3.00   8.0   2   7   0  n   2   1  y  y  u
# 27       1.0  10.00  10.0   3   7   0  n   5   2  y  n  y
# 28       NaN   2.00  10.0   6   5   0  n   4   1  y  y  u
# 29       NaN   0.75  10.0   0   3   0  n   2   1  y  y  u
# 30       0.0   1.50   0.0   3   3   3  y   2   1  y  y  n
# 31       1.0  12.00  10.0   2   0   0  n   2   1  n  n  y
# 32       0.0   1.50   2.0   7  14   0  n   2   0  y  y  n
# 33       NaN   2.00  10.0   3   5   2  n   2   1  y  y  u
# 34       NaN   1.75   8.0   0   0   1  n   1   1  y  y  u
# 35       1.0   2.00   4.0   6   3   1  n   5   3  n  y  y
# 36       NaN   0.50  10.0   5   7   0  n   2   0  y  n  u
# 37       0.0   1.50   8.0   5   6   2  n   2   0  y  y  n
# 38       1.0   2.00  37.0  10   5   0  n   5   2  y  n  y
# 39       NaN   0.75   0.5   3   5   2  n   6   2  y  n  u
# 40       0.0   1.20   0.0   8   2   0  n   2   1  n  y  n
# 41       NaN   0.25  10.0   8   3   0  n   3   0  y  y  u
# 42       1.0   2.00   2.0   5   4   1  n   6   3  n  y  y
# 43       0.0  15.00  12.0   0   5   0  n   5   0  y  n  n
# 44       0.0   5.00   1.5   0   4   0  n   4   1  y  y  n
# 45       0.0   1.00  10.0   5   5   0  n   2   0  y  y  n
# 46       1.0  20.00  28.0   7  14   2  y   3   1  y  y  y
# 47       1.0   1.30   2.0   3   5   0  n   7   3  n  n  y
# 48       0.0   1.00   0.0   4   3   1  n   2   0  y  y  n
# 49       0.0   2.00   5.0  15   1   2  n   1   1  y  y  n
# 50       1.0   5.00   5.0   5   2   1  n   5   3  n  y  y
# 51       1.0   8.00   8.0   4   2   2  n   4   1  n  n  y
# 52       1.0   3.70   2.0   5   1  11  n   2   1  y  y  y
# 53       NaN   6.00   7.0   3   7   0  n   2   1  y  y  u
# 54       NaN   7.00  10.0   1   2   2  n   2   0  y  y  u
# 55       1.0   1.50   5.0  10   5   0  n   6   3  n  n  y
# 56       NaN   0.30  16.0   8   3   0  n   4   1  y  y  u
# 57       1.0   1.10   1.0   4   3   0  n   3   3  y  n  y
# 58       1.0   0.50  15.0   3   3   0  n   4   2  y  y  y
# 59       1.0   4.00   8.0  16   7   1  n   4   1  y  y  y

# %%
# 修改数据标识, 方便识别
data.loc[data.ge_gender=='f','ge_gender'] = '1_female' 
data.loc[data.ge_gender=='m','ge_gender'] = '0_male' 
data.loc[data.pa_political_affiliation=='d','pa_political_affiliation'] = 'Democrat' 
data.loc[data.pa_political_affiliation=='r','pa_political_affiliation'] = 'Republican' 
data.loc[data.pa_political_affiliation=='i','pa_political_affiliation'] = 'Independent' 
data
# Out:
#     subj  co_college_GPA  co_college_GPA_100  hi_high_school_GPA ge_gender  \
# 0      1             3.5                87.5                 2.2    0_male
# 1      2             3.5                87.5                 2.1  1_female
# 2      3             3.0                75.0                 3.3  1_female
# 3      4             3.2                80.0                 3.5  1_female
# 4      5             3.5                87.5                 3.1    0_male
# 5      6             3.5                87.5                 3.5    0_male
# 6      7             3.7                92.5                 3.6    0_male
# 7      8             3.0                75.0                 3.0  1_female
# 8      9             3.0                75.0                 3.0    0_male
# 9     10             3.1                77.5                 4.0    0_male
# 10    11             2.6                65.0                 2.3    0_male
# 11    12             3.6                90.0                 3.5  1_female
# 12    13             3.5                87.5                 3.3    0_male
# 13    14             3.2                80.0                 3.2    0_male
# 14    15             3.5                87.5                 3.0  1_female
# 15    16             3.3                82.5                 3.8  1_female
# 16    17             3.0                75.0                 4.0  1_female
# 17    18             3.8                95.0                 3.8    0_male
# 18    19             3.5                87.5                 4.0    0_male
# 19    20             3.8                95.0                 3.0  1_female
# 20    21             3.7                92.5                 3.7  1_female
# 21    22             3.7                92.5                 4.0  1_female
# 22    23             3.5                87.5                 2.7    0_male
# 23    24             3.7                92.5                 3.7  1_female
# 24    25             3.8                95.0                 3.2    0_male
# 25    26             3.0                75.0                 3.0  1_female
# 26    27             3.0                75.0                 3.7    0_male
# 27    28             3.8                95.0                 3.7  1_female
# 28    29             3.1                77.5                 3.3    0_male
# 29    30             3.3                82.5                 3.3  1_female
# 30    31             3.5                87.5                 3.3    0_male
# 31    32             3.9                97.5                 3.5  1_female
# 32    33             3.4                85.0                 3.4    0_male
# 33    34             2.8                70.0                 3.2  1_female
# 34    35             3.9                97.5                 3.5  1_female
# 35    36             3.3                82.5                 3.6    0_male
# 36    37             3.7                92.5                 3.8    0_male
# 37    38             3.4                85.0                 3.4    0_male
# 38    39             3.2                80.0                 2.8    0_male
# 39    40             3.5                87.5                 3.8    0_male
# 40    41             3.4                85.0                 3.4    0_male
# 41    42             3.0                75.0                 2.0    0_male
# 42    43             3.9                97.5                 3.8  1_female
# 43    44             3.6                90.0                 3.0    0_male
# 44    45             4.0               100.0                 3.0  1_female
# 45    46             3.5                87.5                 3.0  1_female
# 46    47             3.8                95.0                 3.0  1_female
# 47    48             3.8                95.0                 3.3    0_male
# 48    49             4.0               100.0                 3.8  1_female
# 49    50             4.0               100.0                 3.0  1_female
# 50    51             3.0                75.0                 3.0    0_male
# 51    52             4.0               100.0                 4.0  1_female
# 52    53             3.9                97.5                 3.0  1_female
# 53    54             3.8                95.0                 3.5  1_female
# 54    55             3.7                92.5                 3.4  1_female
# 55    56             3.2                80.0                 3.6  1_female
# 56    57             3.6                90.0                 3.5    0_male
# 57    58             3.0                75.0                 3.0    0_male
# 58    59             3.0                75.0                 3.0  1_female
# 59    60             3.0                75.0                 3.4  1_female
#
#    pa_political_affiliation  ag_age  dh_distance_of_campus_from_home  \
# 0                Republican      32                                0
# 1                  Democrat      23                             1200
# 2                  Democrat      27                             1300
# 3               Independent      35                             1500
# 4               Independent      23                             1600
# 5                  Democrat      39                              350
# 6               Independent      24                                0
# 7               Independent      31                             5000
# 8               Independent      34                             5000
# 9               Independent      28                              900
# 10               Republican      23                              253
# 11                 Democrat      27                              190
# 12                 Democrat      36                              245
# 13              Independent      28                              500
# 14                 Democrat      28                             3500
# 15              Independent      25                              210
# 16              Independent      41                             1000
# 17                 Democrat      50                                0
# 18              Independent      71                             5000
# 19                 Democrat      28                              120
# 20              Independent      26                             8000
# 21              Independent      27                                2
# 22               Republican      31                             1700
# 23              Independent      23                                2
# 24              Independent      23                              450
# 25              Independent      44                                0
# 26                 Democrat      26                             1000
# 27               Republican      31                              850
# 28                 Democrat      24                              420
# 29               Republican      26                             1200
# 30                 Democrat      26                             1000
# 31                 Democrat      32                              150
# 32                 Democrat      26                             2000
# 33              Independent      22                              316
# 34                 Democrat      24                              900
# 35               Republican      24                              250
# 36              Independent      23                              180
# 37              Independent      33                             6000
# 38               Republican      23                              950
# 39               Republican      31                             1100
# 40              Independent      26                             1300
# 41                 Democrat      28                              360
# 42               Republican      24                             1800
# 43               Republican      23                              900
# 44              Independent      25                             5000
# 45                 Democrat      24                              300
# 46               Republican      27                             2000
# 47               Republican      24                              630
# 48                 Democrat      26                             1200
# 49                 Democrat      27                              580
# 50               Republican      32                             2000
# 51               Republican      41                                0
# 52                 Democrat      29                              300
# 53                 Democrat      50                                6
# 54              Independent      22                               80
# 55               Republican      23                              375
# 56                 Democrat      26                             2000
# 57              Independent      30                                1
# 58              Independent      23                              112
# 59              Independent      22                              650
#
#     religion     dr    tv  sp  ne  ah ve  pi  re ab aa ld
# 0        1.0   5.00   3.0   5   0   0  n   6   2  n  n  y
# 1        NaN   0.30  15.0   7   5   6  y   2   1  y  y  u
# 2        NaN   1.50   0.0   4   3   0  y   2   2  y  y  u
# 3        0.0   8.00   5.0   5   6   3  n   4   1  y  y  n
# 4        0.0  10.00   6.0   6   3   0  n   1   0  y  n  n
# 5        NaN   3.00   4.0   5   7   0  y   2   1  y  y  u
# 6        1.0   0.20   5.0  12   4   2  n   2   1  y  y  y
# 7        1.0   1.50   5.0   3   3   1  n   2   1  y  y  y
# 8        NaN   2.00   7.0   5   3   0  n   1   1  y  y  u
# 9        1.0   2.00   1.0   1   2   1  y   3   0  n  y  y
# 10       1.0   1.50  10.0  15   1   1  n   5   1  n  y  y
# 11       NaN   3.00  14.0   3   7   0  n   2   1  y  y  u
# 12       1.0   1.50   6.0  15  12   5  n   1   1  y  y  y
# 13       1.0   6.00   3.0  10   1   2  n   4   1  y  n  y
# 14       1.0   1.00   4.0   3   1   0  n   1   0  y  y  y
# 15       1.0  10.00   7.0   6   1   0  y   2   3  y  y  y
# 16       1.0  15.00   6.0   7   3  10  n   3   3  n  u  y
# 17       0.0   3.00   5.0   9   6  10  n   2   0  y  n  n
# 18       0.0   3.00   6.0  12   2   2  n   2   0  y  n  n
# 19       1.0   1.00  25.0   0   0   2  y   1   1  y  y  y
# 20       1.0   8.00   4.0   4   4   1  n   4   1  y  y  y
# 21       1.0   2.50   4.0   2   7   0  n   2   1  y  y  y
# 22       1.0   5.00   7.0   7   2   0  n   7   3  n  n  y
# 23       1.0   2.00   7.0   4   2   0  n   4   0  y  y  y
# 24       1.0   4.00   0.0   7   7   3  n   1   0  y  y  y
# 25       1.0   2.00   2.0   3   2   3  y   3   2  y  y  y
# 26       NaN   3.00   8.0   2   7   0  n   2   1  y  y  u
# 27       1.0  10.00  10.0   3   7   0  n   5   2  y  n  y
# 28       NaN   2.00  10.0   6   5   0  n   4   1  y  y  u
# 29       NaN   0.75  10.0   0   3   0  n   2   1  y  y  u
# 30       0.0   1.50   0.0   3   3   3  y   2   1  y  y  n
# 31       1.0  12.00  10.0   2   0   0  n   2   1  n  n  y
# 32       0.0   1.50   2.0   7  14   0  n   2   0  y  y  n
# 33       NaN   2.00  10.0   3   5   2  n   2   1  y  y  u
# 34       NaN   1.75   8.0   0   0   1  n   1   1  y  y  u
# 35       1.0   2.00   4.0   6   3   1  n   5   3  n  y  y
# 36       NaN   0.50  10.0   5   7   0  n   2   0  y  n  u
# 37       0.0   1.50   8.0   5   6   2  n   2   0  y  y  n
# 38       1.0   2.00  37.0  10   5   0  n   5   2  y  n  y
# 39       NaN   0.75   0.5   3   5   2  n   6   2  y  n  u
# 40       0.0   1.20   0.0   8   2   0  n   2   1  n  y  n
# 41       NaN   0.25  10.0   8   3   0  n   3   0  y  y  u
# 42       1.0   2.00   2.0   5   4   1  n   6   3  n  y  y
# 43       0.0  15.00  12.0   0   5   0  n   5   0  y  n  n
# 44       0.0   5.00   1.5   0   4   0  n   4   1  y  y  n
# 45       0.0   1.00  10.0   5   5   0  n   2   0  y  y  n
# 46       1.0  20.00  28.0   7  14   2  y   3   1  y  y  y
# 47       1.0   1.30   2.0   3   5   0  n   7   3  n  n  y
# 48       0.0   1.00   0.0   4   3   1  n   2   0  y  y  n
# 49       0.0   2.00   5.0  15   1   2  n   1   1  y  y  n
# 50       1.0   5.00   5.0   5   2   1  n   5   3  n  y  y
# 51       1.0   8.00   8.0   4   2   2  n   4   1  n  n  y
# 52       1.0   3.70   2.0   5   1  11  n   2   1  y  y  y
# 53       NaN   6.00   7.0   3   7   0  n   2   1  y  y  u
# 54       NaN   7.00  10.0   1   2   2  n   2   0  y  y  u
# 55       1.0   1.50   5.0  10   5   0  n   6   3  n  n  y
# 56       NaN   0.30  16.0   8   3   0  n   4   1  y  y  u
# 57       1.0   1.10   1.0   4   3   0  n   3   3  y  n  y
# 58       1.0   0.50  15.0   3   3   0  n   4   2  y  y  y
# 59       1.0   4.00   8.0  16   7   1  n   4   1  y  y  y

# %% [markdown]
# ### 单因素卡方检验
# * 原假设: Democrat占40%, Republican占40%, Independent占20%

# %%
data1 = data[['subj', 'pa_political_affiliation']]
data1
# Out:
#     subj pa_political_affiliation
# 0      1               Republican
# 1      2                 Democrat
# 2      3                 Democrat
# 3      4              Independent
# 4      5              Independent
# 5      6                 Democrat
# 6      7              Independent
# 7      8              Independent
# 8      9              Independent
# 9     10              Independent
# 10    11               Republican
# 11    12                 Democrat
# 12    13                 Democrat
# 13    14              Independent
# 14    15                 Democrat
# 15    16              Independent
# 16    17              Independent
# 17    18                 Democrat
# 18    19              Independent
# 19    20                 Democrat
# 20    21              Independent
# 21    22              Independent
# 22    23               Republican
# 23    24              Independent
# 24    25              Independent
# 25    26              Independent
# 26    27                 Democrat
# 27    28               Republican
# 28    29                 Democrat
# 29    30               Republican
# 30    31                 Democrat
# 31    32                 Democrat
# 32    33                 Democrat
# 33    34              Independent
# 34    35                 Democrat
# 35    36               Republican
# 36    37              Independent
# 37    38              Independent
# 38    39               Republican
# 39    40               Republican
# 40    41              Independent
# 41    42                 Democrat
# 42    43               Republican
# 43    44               Republican
# 44    45              Independent
# 45    46                 Democrat
# 46    47               Republican
# 47    48               Republican
# 48    49                 Democrat
# 49    50                 Democrat
# 50    51               Republican
# 51    52               Republican
# 52    53                 Democrat
# 53    54                 Democrat
# 54    55              Independent
# 55    56               Republican
# 56    57                 Democrat
# 57    58              Independent
# 58    59              Independent
# 59    60              Independent

# %%
data1.groupby('pa_political_affiliation').count()
# Out:
#                           subj
# pa_political_affiliation
# Democrat                    21
# Independent                 24
# Republican                  15

# %%
from scipy import stats
stats.chisquare(f_obs=[21,15,24], f_exp=[60*0.40, 60*0.40, 60*0.20])
# Out:
# Power_divergenceResult(statistic=15.75, pvalue=0.0003801289578694638)

# %% [markdown]
# * p值远小于0.05, 拒绝原假设

# %% [markdown]
# ### 双因素卡方检验
# * 性别和政党归属相关吗?
# * 原假设: 性别和政党归属不相关(两个因素相互独立)

# %%
data2 = data[['subj', 'ge_gender','pa_political_affiliation']]
data2
# Out:
#     subj ge_gender pa_political_affiliation
# 0      1    0_male               Republican
# 1      2  1_female                 Democrat
# 2      3  1_female                 Democrat
# 3      4  1_female              Independent
# 4      5    0_male              Independent
# 5      6    0_male                 Democrat
# 6      7    0_male              Independent
# 7      8  1_female              Independent
# 8      9    0_male              Independent
# 9     10    0_male              Independent
# 10    11    0_male               Republican
# 11    12  1_female                 Democrat
# 12    13    0_male                 Democrat
# 13    14    0_male              Independent
# 14    15  1_female                 Democrat
# 15    16  1_female              Independent
# 16    17  1_female              Independent
# 17    18    0_male                 Democrat
# 18    19    0_male              Independent
# 19    20  1_female                 Democrat
# 20    21  1_female              Independent
# 21    22  1_female              Independent
# 22    23    0_male               Republican
# 23    24  1_female              Independent
# 24    25    0_male              Independent
# 25    26  1_female              Independent
# 26    27    0_male                 Democrat
# 27    28  1_female               Republican
# 28    29    0_male                 Democrat
# 29    30  1_female               Republican
# 30    31    0_male                 Democrat
# 31    32  1_female                 Democrat
# 32    33    0_male                 Democrat
# 33    34  1_female              Independent
# 34    35  1_female                 Democrat
# 35    36    0_male               Republican
# 36    37    0_male              Independent
# 37    38    0_male              Independent
# 38    39    0_male               Republican
# 39    40    0_male               Republican
# 40    41    0_male              Independent
# 41    42    0_male                 Democrat
# 42    43  1_female               Republican
# 43    44    0_male               Republican
# 44    45  1_female              Independent
# 45    46  1_female                 Democrat
# 46    47  1_female               Republican
# 47    48    0_male               Republican
# 48    49  1_female                 Democrat
# 49    50  1_female                 Democrat
# 50    51    0_male               Republican
# 51    52  1_female               Republican
# 52    53  1_female                 Democrat
# 53    54  1_female                 Democrat
# 54    55  1_female              Independent
# 55    56  1_female               Republican
# 56    57    0_male                 Democrat
# 57    58    0_male              Independent
# 58    59  1_female              Independent
# 59    60  1_female              Independent

# %%
#  第一步, 创建交叉报表
#  进行双因素卡方检验前，需要将频数分类别统计好, 一般可用pd.crosstab() 完成
table = pd.crosstab(index=data2.ge_gender, columns=data2.pa_political_affiliation) 
# 按类别计数
table
# Out:
# pa_political_affiliation  Democrat  Independent  Republican
# ge_gender
# 0_male                           9           11           9
# 1_female                        12           13           6

# %%
#  第二步, 双因素卡方检验
stats.chi2_contingency(table)
# Out:
# (1.1298267916732878,
#  0.5684093712440272,
#  2,
#  array([[10.15, 11.6 ,  7.25],
#         [10.85, 12.4 ,  7.75]]))

# %% [markdown]
# * 输出结果: 卡方值, p值, 自由度, 预期的数量
# * p值大于0.05, 接受原假设, 性别和政党归属不相关

# %% [markdown]
# ### 双因素卡方检验-使用pingouin
# * 不需要手动创建交叉报表
# * pearson卡方检验与stats.chi2_contingency()一致

# %%
import pingouin as pg
pg.chi2_independence(data2, x='ge_gender',  y='pa_political_affiliation')
# Out:
# (pa_political_affiliation  Democrat  Independent  Republican
#  ge_gender
#  0_male                       10.15         11.6        7.25
#  1_female                     10.85         12.4        7.75,
#  pa_political_affiliation  Democrat  Independent  Republican
#  ge_gender
#  0_male                           9           11           9
#  1_female                        12           13           6,
#                   test    lambda      chi2  dof      pval    cramer     power
#  0             pearson  1.000000  1.129827  2.0  0.568409  0.137224  0.144357
#  1        cressie-read  0.666667  1.130416  2.0  0.568242  0.137260  0.144410
#  2      log-likelihood  0.000000  1.134288  2.0  0.567143  0.137495  0.144760
#  3       freeman-tukey -0.500000  1.139583  2.0  0.565643  0.137815  0.145238
#  4  mod-log-likelihood -1.000000  1.146974  2.0  0.563557  0.138261  0.145906
#  5              neyman -2.000000  1.168267  2.0  0.557589  0.139539  0.147835)

# %% [markdown]
# # 有序数据的非参数检验

# %% [markdown]
# ## 单样本的总体分布检验
# * 单样本符号检验
#     * 原理类似符号检验(见下文)
#     * 分数大于假定数时记为+, 分数小于假定数时记为-
#     * 原假设(假定数是中位数)正确时, 符合+与-的比例各占50%, 可用二项检验推断原假设
# * 单样本Wilcoxon检验:
#     * 原理类似Wilcoxon符号秩检验
#     * 差异等级 = 个体的|观测值-总体中位数|的等级
# * 游程检验(run test)
# * Kolmogorov—Smirnov检验(单样本K-S检验)

# %%
data=[44.21,45.30,46.39,49.47,51.05,53.16,53.26,54.37,57.16,67.37,71.05,87.37]
# 样本对应总体的中位数是否等于45.30?
# 原假设: 样本对应总体的中位数=45.30
from scipy import stats
import numpy as np
stats.wilcoxon(np.array(data)-45.30,correction=True)

# %%
import pingouin as pg   # 另一选择,可输出效应大小
pg.wilcoxon(np.array(data)-45.30)

# %% [markdown]
# ## 两独立样本的差异性检验
# * Mann-Whitney U 检验:
#     * 也叫: Mann-Whitney-Wilcoxon检验, Wilcoxon秩和检验(Wilcoxon rank-sum test)
#     * 原理: 两总体无差异时, 两样本数据(大小排序后)均匀混合在一起; 两总体极端不同时, 两样本(大小排序后)分散在两端(较小U值)
#     * 统计量U值=min(样本A的U, 样本B的U), 样本A的U = 样本A中个体大于样本B中个体的总次数
#     * 较小的U值(接近零)证明原假设(两总体无差异)不成立
# * Wald-Wolfowitz Runs 检验
# * Kolmogorov—Smirnov 检验
# * Moses Extreme Reactions 检验

# %%
# 原假设: 两独立样本对应总体无差异
from scipy import stats
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]
stats.mannwhitneyu(data1, data2)
# Out:
# MannwhitneyuResult(statistic=40.0, pvalue=0.47267559351158717)

# %% [markdown]
# ## 两配对样本的差异性检验(重复测量样本)
# * 符号检验(sign test):
#     * 场景: 对每一被试, 只知道样本1与样本2谁大、不知道大多少时, 可用于替代"两配对样本t检验"
#     * 对每一被试, 样本2大于样本1得分时记为+, 样本2小于样本1得分时记为-
#     * 原假设(两总体无差异)正确时, 符合+与-的比例各占50%, 可用二项检验推断原假设
# * Wilcoxon符号秩检验(Wilcoxon signed-rank test):
#     * 场景: 差异分数可按大小排序时(但差异分数不是等距数据)
#     * 差异等级 = 个体|样本1-样本2|的等级, 根据符号(正负号)分成正差异、负差异,  统计量T值=min(正差异等级的累积,负差异等级的累积)
#     * 较小的T值(接近零)证明原假设(两总体无差异)不成立
#     * Wilcoxon符号秩检验可用时, 优于符号检验
# * McNemar检验
# * Marginal Homogeneity检验（边际同质性检验）

# %%
# 原假设: 两配对样本对应总体无差异
from scipy import stats
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]
stats.wilcoxon(data1, data2)

# %% [markdown]
# ## 多个独立样本的差异性检验
# * Kruskal-Wallis H 检验:
#     * Kruskal-Wallis单因素秩次方差分析(Kruskal-Wallis one-way analysis of variance by ranks), 是对Mann-Whitney检验的扩展
#     * 将所有样本(处理)的个体混合、排列等级
#     * 计算每个样本的等级总和T, 根据每个样本的T, 计算统计量H值
#     * H值(近似卡方分布)较大, 证明原假设(多个总体无差异)不成立
# * 中位数检验
# * Jonckheere-Terpstra检验

# %% [markdown]
# ### scipy.stats.kruskal()
# * 原始数据为宽型数据

# %%
# 原假设: 多个独立样本对应总体无差异
from scipy import stats
x = [1, 0, 1]
y = [2, 1, 2]
z = [2, 2, 3, 4]
stats.kruskal(x, y, z)

# %%
import pandas as pd
data = pd.DataFrame.from_dict({'x':x, 'y':y, 'z':z}, orient='index')
# orient='index' 每个键值对为1行、允许不等长
data = data.transpose()  # 行列转置
data

# %%
# 基于pandas的数据集
stats.kruskal(data['x'].dropna(), data['y'].dropna(),data['z'].dropna())

# %% [markdown]
# ### pingouin.kruskal()
# * 原始数据为长型数据

# %%
# 将宽型数据转换为长型数据
data1 = data.melt()
data1  # 长型数据, variable是分类, value是取值

# %%
# 原假设: 多个独立样本对应总体无差异
import pingouin as pg
pg.kruskal(data=data1, dv='value', between='variable')

# %% [markdown]
# ## 多个配对样本的差异性检验
# * Friedman检验:
#     * 计算每个被试对应样本(处理)的等级, 例如对被试A, 排出在三个样本下的等级: 1、2、3
#     * 计算每个样本的等级总和R, 根据每个样本的R, 计算统计量$x^2_r$值
#     * $x^2_r$值(近似卡方分布)较大, 证明原假设(多个总体无差异)不成立
# * Cochran Q 检验
# * Kendall协和系数检验

# %%
# 原假设: 多个配对样本对应总体无差异
from scipy import stats
data1 = [0.873, 2.817, 0.121, -0.945, -0.055, -1.436, 0.360, -1.478, -1.637, -1.869]
data2 = [1.142, -0.432, -0.938, -0.729, -0.846, -0.157, 0.500, 1.183, -1.075, -0.169]
data3 = [-0.208, 0.696, 0.928, -1.148, -0.213, 0.229, 0.137, 0.269, -0.870, -1.204]
stats.friedmanchisquare(data1, data2, data3)

# %%
# 原假设: 多个配对样本对应总体无差异
import pandas as pd
data = pd.DataFrame({'data1':data1, 'data2':data2, 'data3':data3})
import pingouin as pg
pg.friedman(data)  # 此处使用宽型数据, 也可使用长型数据
